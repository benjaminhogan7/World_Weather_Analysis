# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import gmaps
import requests

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

#Import CitiPY
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0, 90.0, size =2000)
lngs = np.random.uniform(-90.0, 90.0, size =2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(cities)
# Out:
# ['altay', 'chapais', 'ushuaia', 'taoudenni', 'bethlehem', 'manta', 'urumqi', 'punta arenas', 'aktau', 'padang', 'avon park', 'rawson', 'lucapa', 'saint george', 'port alfred', 'hamilton', 'taolanaro', 'jamestown', 'duz', 'amderma', 'goias', 'tsihombe', 'illoqqortoormiut', 'gornopravdinsk', 'tumba', 'lebu', 'cape town', 'sholokhovskiy', 'pangnirtung', 'arraial do cabo', 'berlevag', 'santiago de cao', 'caravelas', 'saint-philippe', 'klaksvik', 'georgetown', 'cayenne', 'niamey', 'gulbene', 'busselton', 'bredasdorp', 'mosquera', 'tasiilaq', 'margate', 'torbay', 'warri', 'sisimiut', 'sinkat', 'mar del plata', 'hermanus', 'vardo', 'huarmey', 'christiana', 'agdam', 'pisco', 'jerusalem', 'namibe', 'qaanaaq', 'sibut', 'umzimvubu', 'kindu', 'murfreesboro', 'kotelnikovo', 'ballinasloe', 'puerto del rosario', 'port elizabeth', 'belushya guba', 'plettenberg bay', 'bolungarvik', 'jalu', 'isla mujeres', 'clyde river', 'surt', 'castro', 'concordia', 'vestmanna', 'carnarvon', 'massaguet', 'torez', 'alto vera', 'iqaluit', 'rocha', 'karkaralinsk', 'tumannyy', 'ilulissat', 'warmbad', 'dikson', 'attawapiskat', 'guarapari', 'toliary', 'rusape', 'bathsheba', 'kashi', 'talara', 'adeje', 'dekar', 'hofn', 'oranjemund', 'sechura', 'grand river south east', 'azimur', 'cumbitara', 'cumaribo', 'huicungo', 'tikrit', 'soyo', 'atasu', 'isselburg', 'topchikha', 'cidreira', 'hithadhoo', 'naryan-mar', 'dudinka', 'buqayq', 'ribeira grande', 'iskateley', 'victoria', 'galle', 'ati', 'forestville', 'vieste', 'yarada', 'bosaso', 'bambous virieux', 'laukaa', 'canto do buriti', 'yenagoa', 'gazli', 'thompson', 'tazovskiy', 'aripuana', 'machico', 'villazon', 'goderich', 'toftir', 'cap malheureux', 'emmaus', 'male', 'nador', 'pinega', 'kingston', 'imbituva', 'kubrat', 'tulum', 'souillac', 'barentsburg', 'longyearbyen', 'upernavik', 'lasa', 'sambava', 'kisangani', 'camacha', 'vila velha', 'omboue', 'monrovia', 'mutoko', 'marquette', 'qazvin', 'marcona', 'coquimbo', 'santiago del estero', 'rabo de peixe', 'laguna', 'taltal', 'puerto ayacucho', 'mehran', 'mangrol', 'nalut', 'nyanza', 'ust-koksa', 'lai', 'aljezur', 'dera bugti', 'mulchen', 'muyezerskiy', 'gornyak', 'mahebourg', 'george town', 'diamantino', 'adrar', 'coihaique', 'qeshm', 'kuli', 'mahroni', 'bandarbeyla', 'arlit', 'labrea', 'kalas', 'high rock', 'taboao da serra', 'winchester', 'kalemie', 'butterworth', 'yanam', 'codrington', 'vila franca do campo', 'syracuse', 'vila do maio', 'le port', 'coria', 'dois vizinhos', 'ylivieska', 'faya', 'mallaig', 'salalah', 'smolenskaya', 'lagoa', 'mwinilunga', 'higuey', 'chuy', 'sinnamary', 'wageningen', 'sao filipe', 'sarakhs', 'sorumsand', 'kachiry', 'saint-francois', 'hare bay', 'gangotri', 'sept-iles', 'cuiaba', 'muravlenko', 'bara', 'changji', 'kruisfontein', 'san juan bautista', 'sorland', 'saldanha', 'ramban', 'karakol', 'taurage', 'leh', 'inhambane', 'sankt florian', 'den helder', 'banda aceh', 'oneonta', 'rundu', 'ostersund', 'ponta do sol', 'saint-augustin', 'jizan', 'waspan', 'sakakah', 'west bay', 'kavaratti', 'grindavik', 'henties bay', 'abu jubayhah', 'hanko', 'saryozek', 'camapua', 'betsiamites', 'east london', 'peniche', 'luanshya', 'cape coast', 'nanortalik', 'kenitra', 'akureyri', 'malakal', 'brigantine', 'goya', 'roald', 'oriximina', 'puerto madryn', 'sao borja', 'marsa matruh', 'umm lajj', 'alekseyevka', 'tabou', 'mango', 'rio branco', 'reo', 'husavik', 'progreso', 'luanda', 'bud', 'hammerfest', 'malanje', 'hambantota', 'ostrovnoy', 'coari', 'pontivy', 'narsaq', 'kortkeros', 'yellamanchili', 'camacupa', 'chynov', 'malwan', 'beira', 'hobyo', 'kyshtovka', 'san cristobal', 'svoge', 'louisbourg', 'mizdah', 'acarau', 'maniitsoq', 'tessalit', 'marsh harbour', 'turbat', 'thinadhoo', 'sao joao da barra', 'walvis bay', 'lerwick', 'ustyuzhna', 'saint anthony', 'bani', 'igarka', 'korla', 'outjo', 'najran', 'praia da vitoria', 'millinocket', 'inirida', 'suffolk', 'butgenbach', 'mucurapo', 'sur', 'tukrah', 'bushehr', 'itarema', 'thunder bay', 'berbera', 'opuwo', 'desdunes ...

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=50859762553c8e3be1ca8fd0ba6e1e28

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_weather_description = city_weather['weather'][0]['description']
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | altay
# Processing Record 2 of Set 1 | chapais
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | taoudenni
# Processing Record 5 of Set 1 | bethlehem
# Processing Record 6 of Set 1 | manta
# Processing Record 7 of Set 1 | urumqi
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | aktau
# Processing Record 10 of Set 1 | padang
# Processing Record 11 of Set 1 | avon park
# Processing Record 12 of Set 1 | rawson
# Processing Record 13 of Set 1 | lucapa
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | hamilton
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | duz
# City not found. Skipping...
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | goias
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | gornopravdinsk
# Processing Record 25 of Set 1 | tumba
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | sholokhovskiy
# Processing Record 29 of Set 1 | pangnirtung
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | berlevag
# Processing Record 32 of Set 1 | santiago de cao
# Processing Record 33 of Set 1 | caravelas
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | cayenne
# Processing Record 38 of Set 1 | niamey
# Processing Record 39 of Set 1 | gulbene
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | mosquera
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | margate
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | warri
# Processing Record 47 of Set 1 | sisimiut
# Processing Record 48 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | vardo
# Processing Record 2 of Set 2 | huarmey
# Processing Record 3 of Set 2 | christiana
# Processing Record 4 of Set 2 | agdam
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | jerusalem
# Processing Record 7 of Set 2 | namibe
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | sibut
# Processing Record 10 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 2 | kindu
# Processing Record 12 of Set 2 | murfreesboro
# Processing Record 13 of Set 2 | kotelnikovo
# Processing Record 14 of Set 2 | ballinasloe
# Processing Record 15 of Set 2 | puerto del rosario
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | plettenberg bay
# Processing Record 19 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 2 | jalu
# Processing Record 21 of Set 2 | isla mujeres
# Processing Record 22 of Set 2 | clyde river
# Processing Record 23 of Set 2 | surt
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | concordia
# Processing Record 26 of Set 2 | vestmanna
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | massaguet
# Processing Record 29 of Set 2 | torez
# Processing Record 30 of Set 2 | alto vera
# City not found. Skipping...
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | rocha
# Processing Record 33 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | warmbad
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 2 | guarapari
# Processing Record 40 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 2 | rusape
# Processing Record 42 of Set 2 | bathsheba
# Processing Record 43 of Set 2 | kashi
# Processing Record 44 of Set 2 | talara
# Processing Record 45 of Set 2 | adeje
# Processing Record 46 of Set 2 | dekar
# Processing Record 47 of Set 2 | hofn
# Processing Record 48 of Set 2 | oranjemund
# Processing Record 49 of Set 2 | sechura
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 3 | cumbitara
# Processing Record 3 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 4 of Set 3 | huicungo
# Processing Record 5 of Set 3 | tikrit
# Processing Record 6 of Set 3 | soyo
# Processing Record 7 of Set 3 | atasu
# Processing Record 8 of Set 3 | isselburg
# Processing Record 9 of Set 3 | topchikha
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | naryan-mar
# Processing Record 13 of Set 3 | dudinka
# Processing Record 14 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | iskateley
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | galle
# Processing Record 19 of Set 3 | ati
# Processing Record 20 of Set 3 | forestville
# Processing Record 21 of Set 3 | vieste
# Processing Record 22 of Set 3 | yarada
# Processing Record 23 of Set 3 | bosaso
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | laukaa
# Processing Record 26 of Set 3 | canto do buriti
# Processing Record 27 of Set 3 | yenagoa
# Processing Record 28 of Set 3 | gazli
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | tazovskiy
# Processing Record 31 of Set 3 | aripuana
# Processing Record 32 of Set 3 | machico
# Processing Record 33 of Set 3 | villazon
# Processing Record 34 of Set 3 | goderich
# Processing Record 35 of Set 3 | toftir
# City not found. Skipping...
# Processing Record 36 of Set 3 | cap malheureux
# Processing Record 37 of Set 3 | emmaus
# Processing Record 38 of Set 3 | male
# Processing Record 39 of Set 3 | nador
# Processing Record 40 of Set 3 | pinega
# Processing Record 41 of Set 3 | kingston
# Processing Record 42 of Set 3 | imbituva
# Processing Record 43 of Set 3 | kubrat
# Processing Record 44 of Set 3 | tulum
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | lasa
# Processing Record 50 of Set 3 | sambava
# Processing Record 1 of Set 4 | kisangani
# Processing Record 2 of Set 4 | camacha
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | omboue
# Processing Record 5 of Set 4 | monrovia
# Processing Record 6 of Set 4 | mutoko
# Processing Record 7 of Set 4 | marquette
# Processing Record 8 of Set 4 | qazvin
# Processing Record 9 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 4 | coquimbo
# Processing Record 11 of Set 4 | santiago del estero
# Processing Record 12 of Set 4 | rabo de peixe
# Processing Record 13 of Set 4 | laguna
# Processing Record 14 of Set 4 | taltal
# Processing Record 15 of Set 4 | puerto ayacucho
# Processing Record 16 of Set 4 | mehran
# Processing Record 17 of Set 4 | mangrol
# Processing Record 18 of Set 4 | nalut
# Processing Record 19 of Set 4 | nyanza
# Processing Record 20 of Set 4 | ust-koksa
# Processing Record 21 of Set 4 | lai
# Processing Record 22 of Set 4 | aljezur
# Processing Record 23 of Set 4 | dera bugti
# Processing Record 24 of Set 4 | mulchen
# Processing Record 25 of Set 4 | muyezerskiy
# Processing Record 26 of Set 4 | gornyak
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | george town
# Processing Record 29 of Set 4 | diamantino
# Processing Record 30 of Set 4 | adrar
# Processing Record 31 of Set 4 | coihaique
# Processing Record 32 of Set 4 | qeshm
# Processing Record 33 of Set 4 | kuli
# Processing Record 34 of Set 4 | mahroni
# Processing Record 35 of Set 4 | bandarbeyla
# Processing Record 36 of Set 4 | arlit
# Processing Record 37 of Set 4 | labrea
# Processing Record 38 of Set 4 | kalas
# Processing Record 39 of Set 4 | high rock
# Processing Record 40 of Set 4 | taboao da serra
# Processing Record 41 of Set 4 | winchester
# Processing Record 42 of Set 4 | kalemie
# Processing Record 43 of Set 4 | butterworth
# Processing Record 44 of Set 4 | yanam
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | vila franca do campo
# Processing Record 47 of Set 4 | syracuse
# Processing Record 48 of Set 4 | vila do maio
# Processing Record 49 of Set 4 | le port
# Processing Record 50 of Set 4 | coria
# Processing Record 1 of Set 5 | dois vizinhos
# Processing Record 2 of Set 5 | ylivieska
# Processing Record 3 of Set 5 | faya
# Processing Record 4 of Set 5 | mallaig
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | smolenskaya
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | mwinilunga
# Processing Record 9 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | sinnamary
# Processing Record 12 of Set 5 | wageningen
# Processing Record 13 of Set 5 | sao filipe
# Processing Record 14 of Set 5 | sarakhs
# Processing Record 15 of Set 5 | sorumsand
# Processing Record 16 of Set 5 | kachiry
# Processing Record 17 of Set 5 | saint-francois
# Processing Record 18 of Set 5 | hare bay
# Processing Record 19 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 5 | sept-iles
# Processing Record 21 of Set 5 | cuiaba
# Processing Record 22 of Set 5 | muravlenko
# Processing Record 23 of Set 5 | bara
# Processing Record 24 of Set 5 | changji
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | san juan bautista
# Processing Record 27 of Set 5 | sorland
# Processing Record 28 of Set 5 | saldanha
# Processing Record 29 of Set 5 | ramban
# Processing Record 30 of Set 5 | karakol
# Processing Record 31 of Set 5 | taurage
# Processing Record 32 of Set 5 | leh
# Processing Record 33 of Set 5 | inhambane
# Processing Record 34 of Set 5 | sankt florian
# Processing Record 35 of Set 5 | den helder
# Processing Record 36 of Set 5 | banda aceh
# Processing Record 37 of Set 5 | oneonta
# Processing Record 38 of Set 5 | rundu
# Processing Record 39 of Set 5 | ostersund
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | saint-augustin
# Processing Record 42 of Set 5 | jizan
# Processing Record 43 of Set 5 | waspan
# Processing Record 44 of Set 5 | sakakah
# Processing Record 45 of Set 5 | west bay
# Processing Record 46 of Set 5 | kavaratti
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | henties bay
# Processing Record 49 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 50 of Set 5 | hanko
# Processing Record 1 of Set 6 | saryozek
# Processing Record 2 of Set 6 | camapua
# Processing Record 3 of Set 6 | betsiamites
# Processing Record 4 of Set 6 | east london
# Processing Record 5 of Set 6 | peniche
# Processing Record 6 of Set 6 | luanshya
# Processing Record 7 of Set 6 | cape coast
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | kenitra
# Processing Record 10 of Set 6 | akureyri
# Processing Record 11 of Set 6 | malakal
# Processing Record 12 of Set 6 | brigantine
# Processing Record 13 of Set 6 | goya
# Processing Record 14 of Set 6 | roald
# Processing Record 15 of Set 6 | oriximina
# Processing Record 16 of Set 6 | puerto madryn
# Processing Record 17 of Set 6 | sao borja
# Processing Record 18 of Set 6 | marsa matruh
# Processing Record 19 of Set 6 | umm lajj
# Processing Record 20 of Set 6 | alekseyevka
# Processing Record 21 of Set 6 | tabou
# Processing Record 22 of Set 6 | mango
# Processing Record 23 of Set 6 | rio branco
# Processing Record 24 of Set 6 | reo
# Processing Record 25 of Set 6 | husavik
# Processing Record 26 of Set 6 | progreso
# Processing Record 27 of Set 6 | luanda
# Processing Record 28 of Set 6 | bud
# Processing Record 29 of Set 6 | hammerfest
# Processing Record 30 of Set 6 | malanje
# Processing Record 31 of Set 6 | hambantota
# Processing Record 32 of Set 6 | ostrovnoy
# Processing Record 33 of Set 6 | coari
# Processing Record 34 of Set 6 | pontivy
# Processing Record 35 of Set 6 | narsaq
# Processing Record 36 of Set 6 | kortkeros
# Processing Record 37 of Set 6 | yellamanchili
# City not found. Skipping...
# Processing Record 38 of Set 6 | camacupa
# Processing Record 39 of Set 6 | chynov
# Processing Record 40 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 6 | beira
# Processing Record 42 of Set 6 | hobyo
# Processing Record 43 of Set 6 | kyshtovka
# Processing Record 44 of Set 6 | san cristobal
# Processing Record 45 of Set 6 | svoge
# Processing Record 46 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 6 | mizdah
# Processing Record 48 of Set 6 | acarau
# Processing Record 49 of Set 6 | maniitsoq
# Processing Record 50 of Set 6 | tessalit
# Processing Record 1 of Set 7 | marsh harbour
# Processing Record 2 of Set 7 | turbat
# Processing Record 3 of Set 7 | thinadhoo
# Processing Record 4 of Set 7 | sao joao da barra
# Processing Record 5 of Set 7 | walvis bay
# Processing Record 6 of Set 7 | lerwick
# Processing Record 7 of Set 7 | ustyuzhna
# Processing Record 8 of Set 7 | saint anthony
# Processing Record 9 of Set 7 | bani
# Processing Record 10 of Set 7 | igarka
# Processing Record 11 of Set 7 | korla
# Processing Record 12 of Set 7 | outjo
# Processing Record 13 of Set 7 | najran
# Processing Record 14 of Set 7 | praia da vitoria
# Processing Record 15 of Set 7 | millinocket
# Processing Record 16 of Set 7 | inirida
# Processing Record 17 of Set 7 | suffolk
# Processing Record 18 of Set 7 | butgenbach
# Processing Record 19 of Set 7 | mucurapo
# Processing Record 20 of Set 7 | sur
# Processing Record 21 of Set 7 | tukrah
# Processing Record 22 of Set 7 | bushehr
# Processing Record 23 of Set 7 | itarema
# Processing Record 24 of Set 7 | thunder bay
# Processing Record 25 of Set 7 | berbera
# Processing Record 26 of Set 7 | opuwo
# Processing Record 27 of Set 7 | desdunes
# Processing Record 28 of Set 7 | amarante do maranhao
# Processing Record 29 of Set 7 | urbano santos
# Processing Record 30 of Set 7 | turiacu
# Processing Record 31 of Set 7 | bereda
# Processing Record 32 of Set 7 | mombasa
# Processing Record 33 of Set 7 | porto tolle
# Processing Record 34 of Set 7 | kombissiri
# Processing Record 35 of Set 7 | fuerte olimpo
# Processing Record 36 of Set 7 | san rafael del sur
# Processing Record 37 of Set 7 | villa maria
# Processing Record 38 of Set 7 | asfi
# Processing Record 39 of Set 7 | bondo
# Processing Record 40 of Set 7 | abnub
# Processing Record 41 of Set 7 | sandi
# Processing Record 42 of Set 7 | nyimba
# Processing Record 43 of Set 7 | cocobeach
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | saint-georges
# Processing Record 46 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 7 | lastoursville
# Processing Record 48 of Set 7 | odesskoye
# Processing Record 49 of Set 7 | awjilah
# Processing Record 50 of Set 7 | skjaerhollen
# City not found. Skipping...
# Processing Record 1 of Set 8 | luderitz
# Processing Record 2 of Set 8 | mazyr
# Processing Record 3 of Set 8 | grand gaube
# Processing Record 4 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 5 of Set 8 | skagen
# Processing Record 6 of Set 8 | iringa
# Processing Record 7 of Set 8 | porto novo
# Processing Record 8 of Set 8 | bentiu
# Processing Record 9 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 10 of Set 8 | geraldton
# Processing Record 11 of Set 8 | damavand
# Processing Record 12 of Set 8 | matay
# Processing Record 13 of Set 8 | libertador general san martin
# Processing Record 14 of Set 8 | nacala
# Processing Record 15 of Set 8 | benghazi
# Processing Record 16 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 8 | jodhpur
# Processing Record 18 of Set 8 | dondo
# Processing Record 19 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 8 | gat
# Processing Record 21 of Set 8 | monki
# Processing Record 22 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 8 | tambo
# Processing Record 24 of Set 8 | vila praia de ancora
# Processing Record 25 of Set 8 | zaysan
# Processing Record 26 of Set 8 | uporovo
# Processing Record 27 of Set 8 | yetholm
# City not found. Skipping...
# Processing Record 28 of Set 8 | rio verde de mato grosso
# Processing Record 29 of Set 8 | yangambi
# Processing Record 30 of Set 8 | angoche
# Processing Record 31 of Set 8 | touros
# Processing Record 32 of Set 8 | cockburn town
# Processing Record 33 of Set 8 | iskilip
# Processing Record 34 of Set 8 | roros
# Processing Record 35 of Set 8 | donskoye
# Processing Record 36 of Set 8 | cuxhaven
# Processing Record 37 of Set 8 | rio bueno
# Processing Record 38 of Set 8 | dossor
# Processing Record 39 of Set 8 | trinidad
# Processing Record 40 of Set 8 | chapaevsk
# Processing Record 41 of Set 8 | zarechye
# Processing Record 42 of Set 8 | menongue
# Processing Record 43 of Set 8 | port said
# Processing Record 44 of Set 8 | karpogory
# Processing Record 45 of Set 8 | axim
# Processing Record 46 of Set 8 | mweka
# Processing Record 47 of Set 8 | natal
# Processing Record 48 of Set 8 | jardim
# Processing Record 49 of Set 8 | artvin
# Processing Record 50 of Set 8 | la libertad
# Processing Record 1 of Set 9 | gobabis
# Processing Record 2 of Set 9 | dutlwe
# Processing Record 3 of Set 9 | bengkulu
# Processing Record 4 of Set 9 | sayat
# Processing Record 5 of Set 9 | kalety
# Processing Record 6 of Set 9 | tulnici
# Processing Record 7 of Set 9 | tahoua
# Processing Record 8 of Set 9 | khvoynaya
# Processing Record 9 of Set 9 | abonnema
# Processing Record 10 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 11 of Set 9 | torbat-e jam
# Processing Record 12 of Set 9 | druzhba
# Processing Record 13 of Set 9 | dhidhdhoo
# Processing Record 14 of Set 9 | port-gentil
# Processing Record 15 of Set 9 | clarence town
# Processing Record 16 of Set 9 | gumdag
# Processing Record 17 of Set 9 | doba
# Processing Record 18 of Set 9 | san andres
# Processing Record 19 of Set 9 | torata
# Processing Record 20 of Set 9 | andenes
# Processing Record 21 of Set 9 | mongu
# Processing Record 22 of Set 9 | alma
# Processing Record 23 of Set 9 | kastamonu
# Processing Record 24 of Set 9 | hopkinsville
# Processing Record 25 of Set 9 | mehamn
# Processing Record 26 of Set 9 | barra da estiva
# Processing Record 27 of Set 9 | qasigiannguit
# Processing Record 28 of Set 9 | kuryk
# Processing Record 29 of Set 9 | ciochina
# Processing Record 30 of Set 9 | bloemhof
# Processing Record 31 of Set 9 | nantucket
# Processing Record 32 of Set 9 | mgandu
# Processing Record 33 of Set 9 | marsabit
# Processing Record 34 of Set 9 | obzor
# Processing Record 35 of Set 9 | youkounkoun
# Processing Record 36 of Set 9 | chimoio
# Processing Record 37 of Set 9 | calabozo
# Processing Record 38 of Set 9 | acari
# Processing Record 39 of Set 9 | miraflores
# Processing Record 40 of Set 9 | turka
# Processing Record 41 of Set 9 | trincomalee
# Processing Record 42 of Set 9 | kaniama
# Processing Record 43 of Set 9 | moyale
# Processing Record 44 of Set 9 | zhovti vody
# Processing Record 45 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 9 | tefe
# Processing Record 47 of Set 9 | bardiyah
# Processing Record 48 of Set 9 | benicarlo
# Processing Record 49 of Set 9 | shakawe
# Processing Record 50 of Set 9 | nhlangano
# Processing Record 1 of Set 10 | tombouctou
# Processing Record 2 of Set 10 | chore
# City not found. Skipping...
# Processing Record 3 of Set 10 | atyrau
# Processing Record 4 of Set 10 | rognan
# Processing Record 5 of Set 10 | olinda
# Processing Record 6 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 10 | ayagoz
# Processing Record 8 of Set 10 | umm kaddadah
# Processing Record 9 of Set 10 | quinchia
# Processing Record 10 of Set 10 | kulhudhuffushi
# Processing Record 11 of Set 10 | talcahuano
# Processing Record 12 of Set 10 | kirkwall
# Processing Record 13 of Set 10 | muscat
# Processing Record 14 of Set 10 | matagami
# Processing Record 15 of Set 10 | karmaskaly
# Processing Record 16 of Set 10 | landshut
# Processing Record 17 of Set 10 | yar-sale
# Processing Record 18 of Set 10 | chokwe
# Processing Record 19 of Set 10 | posse
# Processing Record 20 of Set 10 | antalaha
# Processing Record 21 of Set 10 | santa rosa
# Processing Record 22 of Set 10 | pokaran
# Processing Record 23 of Set 10 | mount dora
# Processing Record 24 of Set 10 | santa maria
# Processing Record 25 of Set 10 | baglung
# Processing Record 26 of Set 10 | birao
# Processing Record 27 of Set 10 | ndiekro
# City not found. Skipping...
# Processing Record 28 of Set 10 | havelock
# Processing Record 29 of Set 10 | marsaxlokk
# Processing Record 30 of Set 10 | amapa
# Processing Record 31 of Set 10 | abaetetuba
# Processing Record 32 of Set 10 | wanlaweyn
# Processing Record 33 of Set 10 | caceres
# Processing Record 34 of Set 10 | saint-joseph
# Processing Record 35 of Set 10 | damietta
# Processing Record 36 of Set 10 | mecca
# Processing Record 37 of Set 10 | samana
# Processing Record 38 of Set 10 | buraydah
# Processing Record 39 of Set 10 | mandalgarh
# Processing Record 40 of Set 10 | mount pleasant
# Processing Record 41 of Set 10 | araguaina
# Processing Record 42 of Set 10 | kaliua
# Processing Record 43 of Set 10 | jumla
# Processing Record 44 of Set 10 | talnakh
# Processing Record 45 of Set 10 | ilave
# Processing Record 46 of Set 10 | werda
# Processing Record 47 of Set 10 | altamira
# Processing Record 48 of Set 10 | uusikaupunki
# Processing Record 49 of Set 10 | trairi
# Processing Record 50 of Set 10 | magnor
# Processing Record 1 of Set 11 | saint stephen
# Processing Record 2 of Set 11 | beba
# Processing Record 3 of Set 11 | alta floresta
# Processing Record 4 of Set 11 | yarim
# Processing Record 5 of Set 11 | ler
# Processing Record 6 of Set 11 | fort erie
# Processing Record 7 of Set 11 | hakkari
# Processing Record 8 of Set 11 | yining
# Processing Record 9 of Set 11 | madimba
# Processing Record 10 of Set 11 | doha
# Processing Record 11 of Set 11 | bafoulabe
# Processing Record 12 of Set 11 | llanes
# Processing Record 13 of Set 11 | piracanjuba
# Processing Record 14 of Set 11 | vestmannaeyjar
# Processing Record 15 of Set 11 | lugovoy
# Processing Record 16 of Set 11 | nuuk
# Processing Record 17 of Set 11 | sosnovskoye
# Processing Record 18 of Set 11 | kangaatsiaq
# Processing Record 19 of Set 11 | solhan
# Processing Record 20 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 21 of Set 11 | ugoofaaru
# Processing Record 22 of Set 11 | krasnoselkup
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | yendi
# Processing Record 25 of Set 11 | torva
# Processing Record 26 of Set 11 | tres arroyos
# Processing Record 27 of Set 11 | buchanan
# Processing Record 28 of Set 11 | manjeshwar
# Processing Record 29 of Set 11 | raudeberg
# Processing Record 30 of Set 11 | asuncion
# Processing Record 31 of Set 11 | verkhnetulomskiy
# Processing Record 32 of Set 11 | xapuri
# Processing Record 33 of Set 11 | domoni
# Processing Record 34 of Set 11 | luau
# Processing Record 35 of Set 11 | udala
# Processing Record 36 of Set 11 | bataipora
# Processing Record 37 of Set 11 | gloucester
# Processing Record 38 of Set 11 | harper
# Processing Record 39 of Set 11 | the valley
# Processing Record 40 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 41 of Set 11 | gao
# Processing Record 42 of Set 11 | oktyabrskiy
# Processing Record 43 of Set 11 | carballo
# Processing Record 44 of Set 11 | teguise
# Processing Record 45 of Set 11 | eirunepe
# Processing Record 46 of Set 11 | mahibadhoo
# Processing Record 47 of Set 11 | lagos
# Processing Record 48 of Set 11 | bam
# Processing Record 49 of Set 11 | vermilion
# Processing Record 50 of Set 11 | floresta
# Processing Record 1 of Set 12 | benguela
# Processing Record 2 of Set 12 | strezhevoy
# Processing Record 3 of Set 12 | avesta
# Processing Record 4 of Set 12 | omaruru
# Processing Record 5 of Set 12 | riyadh
# Processing Record 6 of Set 12 | muyinga
# Processing Record 7 of Set 12 | adre
# Processing Record 8 of Set 12 | santa luzia
# Processing Record 9 of Set 12 | jaguaruna
# Processing Record 10 of Set 12 | qaqortoq
# Processing Record 11 of Set 12 | jaque
# Processing Record 12 of Set 12 | shakhtinsk
# Processing Record 13 of Set 12 | jurado
# Processing Record 14 of Set 12 | eyl
# Processing Record 15 of Set 12 | pinyug
# Processing Record 16 of Set 12 | moville
# Processing Record 17 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 18 of Set 12 | salisbury
# Processing Record 19 of Set 12 | pachino
# Processing Record 20 of Set 12 | beyneu
# Processing Record 21 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 12 | korem
# Processing Record 23 of Set 12 | viedma
# Processing Record 24 of Set 12 | gravdal
# Processing Record 25 of Set 12 | morant bay
# Processing Record 26 of Set 12 | antofagasta
# Processing Record 27 of Set 12 | port-cartier
# Processing Record 28 of Set 12 | weligama
# Processing Record 29 of Set 12 | gurupi
# Processing Record 30 of Set 12 | pavlovo
# Processing Record 31 of Set 12 | vigrestad
# Processing Record 32 of Set 12 | manono
# Processing Record 33 of Set 12 | owando
# Processing Record 34 of Set 12 | nosy varika
# Processing Record 35 of Set 12 | cacu
# Processing Record 36 of Set 12 | bodden town
# Processing Record 37 of Set 12 | muros
# Processing Record 38 of Set 12 | santa isabel do rio negro
# Processing Record 39 of Set 12 | mount vernon
# Processing Record 40 of Set 12 | sao miguel do araguaia
# Processing Record 41 of Set 12 | tamandare
# Processing Record 42 of Set 12 | la palma
# Processing Record 43 of Set 12 | camana
# Processing Record 44 of Set 12 | jutai
# Processing Record 45 of Set 12 | nadvoitsy
# Processing Record 46 of Set 12 | dahuk
# Processing Record 47 of Set 12 | virginia beach
# Processing Record 48 of Set 12 | porto torres
# Processing Record 49 of Set 12 | heiligenhafen
# Processing Record 50 of Set 12 | novosheshminsk
# Processing Record 1 of Set 13 | araouane
# Processing Record 2 of Set 13 | san antonio
# Processing Record 3 of Set 13 | benjamin constant
# Processing Record 4 of Set 13 | chimbote
# Processing Record 5 of Set 13 | cochrane
# Processing Record 6 of Set 13 | wilmington
# Processing Record 7 of Set 13 | kurbnesh
# Processing Record 8 of Set 13 | basoko
# Processing Record 9 of Set 13 | kigorobya
# Processing Record 10 of Set 13 | tromso
# Processing Record 11 of Set 13 | kollam
# Processing Record 12 of Set 13 | luangwa
# Processing Record 13 of Set 13 | sitio novo do tocantins
# Processing Record 14 of Set 13 | harindanga
# Processing Record 15 of Set 13 | santa fe
# Processing Record 16 of Set 13 | seaford
# Processing Record 17 of Set 13 | satipo
# Processing Record 18 of Set 13 | svencionys
# Processing Record 19 of Set 13 | buta
# Processing Record 20 of Set 13 | tucurui
# Processing Record 21 of Set 13 | pokhara
# Processing Record 22 of Set 13 | porbandar
# Processing Record 23 of Set 13 | mithimna
# City not found. Skipping...
# Processing Record 24 of Set 13 | peterhead
# Processing Record 25 of Set 13 | marawi
# Processing Record 26 of Set 13 | saint-louis
# Processing Record 27 of Set 13 | meulaboh
# Processing Record 28 of Set 13 | vylgort
# City not found. Skipping...
# Processing Record 29 of Set 13 | keti bandar
# Processing Record 30 of Set 13 | tendukheda
# Processing Record 31 of Set 13 | carbonia
# Processing Record 32 of Set 13 | boca raton
# Processing Record 33 of Set 13 | boden
# Processing Record 34 of Set 13 | schladming
# Processing Record 35 of Set 13 | gairo
# Processing Record 36 of Set 13 | agadez
# Processing Record 37 of Set 13 | morondava
# Processing Record 38 of Set 13 | piacabucu
# Processing Record 39 of Set 13 | calama
# Processing Record 40 of Set 13 | beisfjord
# Processing Record 41 of Set 13 | miandrivazo
# Processing Record 42 of Set 13 | mattru
# Processing Record 43 of Set 13 | porto san giorgio
# Processing Record 44 of Set 13 | barra dos coqueiros
# Processing Record 45 of Set 13 | codajas
# Processing Record 46 of Set 13 | duma
# Processing Record 47 of Set 13 | maloye kozino
# City not found. Skipping...
# Processing Record 48 of Set 13 | manitouwadge
# Processing Record 49 of Set 13 | negombo
# Processing Record 50 of Set 13 | matai
# Processing Record 1 of Set 14 | rio gallegos
# Processing Record 2 of Set 14 | rovaniemi
# Processing Record 3 of Set 14 | uchiza
# Processing Record 4 of Set 14 | maralal
# Processing Record 5 of Set 14 | talavera de la reina
# Processing Record 6 of Set 14 | imeni babushkina
# Processing Record 7 of Set 14 | saint-pierre
# Processing Record 8 of Set 14 | lolodorf
# Processing Record 9 of Set 14 | assomada
# Processing Record 10 of Set 14 | masvingo
# Processing Record 11 of Set 14 | santa isabel
# Processing Record 12 of Set 14 | ampanihy
# Processing Record 13 of Set 14 | englewood
# Processing Record 14 of Set 14 | cabedelo
# Processing Record 15 of Set 14 | rayachoti
# Processing Record 16 of Set 14 | sao felix do xingu
# Processing Record 17 of Set 14 | balod
# Processing Record 18 of Set 14 | severodvinsk
# Processing Record 19 of Set 14 | usinsk
# Processing Record 20 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 21 of Set 14 | hof
# Processing Record 22 of Set 14 | awbari
# Processing Record 23 of Set 14 | guaruja
# Processing Record 24 of Set 14 | nouadhibou
# Processing Record 25 of Set 14 | coihueco
# Processing Record 26 of Set 14 | tandil
# Processing Record 27 of Set 14 | tashara
# Processing Record 28 of Set 14 | knysna
# Processing Record 29 of Set 14 | general roca
# Processing Record 30 of Set 14 | oistins
# Processing Record 31 of Set 14 | borba
# Processing Record 32 of Set 14 | diffa
# Processing Record 33 of Set 14 | ponta delgada
# Processing Record 34 of Set 14 | belyy yar
# Processing Record 35 of Set 14 | goundam
# Processing Record 36 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 14 | carauari
# Processing Record 38 of Set 14 | koboko
# Processing Record 39 of Set 14 | amboasary
# Processing Record 40 of Set 14 | ushtobe
# Processing Record 41 of Set 14 | necochea
# Processing Record 42 of Set 14 | bahir dar
# Processing Record 43 of Set 14 | salima
# Processing Record 44 of Set 14 | aksu
# Processing Record 45 of Set 14 | road town
# Processing Record 46 of Set 14 | chitral
# Processing Record 47 of Set 14 | snezhnogorsk
# Processing Record 48 of Set 14 | penzance
# Processing Record 49 of Set 14 | reggio di calabria
# Processing Record 50 of Set 14 | oshnaviyeh
# Processing Record 1 of Set 15 | bodmin
# Processing Record 2 of Set 15 | pedasi
# Processing Record 3 of Set 15 | olafsvik
# Processing Record 4 of Set 15 | opelika
# Processing Record 5 of Set 15 | paramonga
# Processing Record 6 of Set 15 | smoljan
# Processing Record 7 of Set 15 | anzio
# Processing Record 8 of Set 15 | santa helena de goias
# Processing Record 9 of Set 15 | iberia
# Processing Record 10 of Set 15 | upington
# Processing Record 11 of Set 15 | kurchanskaya
# Processing Record 12 of Set 15 | dwarka
# Processing Record 13 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 14 of Set 15 | ocu
# Processing Record 15 of Set 15 | ladario
# Processing Record 16 of Set 15 | ilo
# Processing Record 17 of Set 15 | semey
# Processing Record 18 of Set 15 | zandvoort
# Processing Record 19 of Set 15 | bayan
# Processing Record 20 of Set 15 | mezen
# Processing Record 21 of Set 15 | correntina
# Processing Record 22 of Set 15 | formosa
# Processing Record 23 of Set 15 | brae
# Processing Record 24 of Set 15 | tucupita
# Processing Record 25 of Set 15 | carutapera
# Processing Record 26 of Set 15 | khandbari
# Processing Record 27 of Set 15 | constitucion
# Processing Record 28 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 29 of Set 15 | mashhad
# Processing Record 30 of Set 15 | ibra
# Processing Record 31 of Set 15 | libreville
# Processing Record 32 of Set 15 | tambacounda
# Processing Record 33 of Set 15 | manaure
# Processing Record 34 of Set 15 | hualmay
# Processing Record 35 of Set 15 | valls
# Processing Record 36 of Set 15 | colares
# Processing Record 37 of Set 15 | skjervoy
# Processing Record 38 of Set 15 | vuktyl
# Processing Record 39 of Set 15 | kemijarvi
# Processing Record 40 of Set 15 | nuqui
# Processing Record 41 of Set 15 | mercedes
# Processing Record 42 of Set 15 | krasnovishersk
# Processing Record 43 of Set 15 | paracuru
# Processing Record 44 of Set 15 | karlstad
# Processing Record 45 of Set 15 | porto velho
# Processing Record 46 of Set 15 | lyngseidet
# Processing Record 47 of Set 15 | uray
# Processing Record 48 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 15 | ust-tsilma
# Processing Record 50 of Set 15 | hessisch oldendorf
# Processing Record 1 of Set 16 | carahue
# Processing Record 2 of Set 16 | perelyub
# Processing Record 3 of Set 16 | bubaque
# Processing Record 4 of Set 16 | kolondieba
# Processing Record 5 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 16 | lerik
# Processing Record 7 of Set 16 | bari
# Processing Record 8 of Set 16 | novyy urengoy
# Processing Record 9 of Set 16 | oskarshamn
# Processing Record 10 of Set 16 | taywarah
# Processing Record 11 of Set 16 | comodoro rivadavia
# Processing Record 12 of Set 16 | chebsara
# Processing Record 13 of Set 16 | sabzevar
# Processing Record 14 of Set 16 | ancud
# Processing Record 15 of Set 16 | burica
# City not found. Skipping...
# Processing Record 16 of Set 16 | kibre mengist
# Processing Record 17 of Set 16 | lethem
# Processing Record 18 of Set 16 | mayumba
# Processing Record 19 of Set 16 | quatre cocos
# Processing Record 20 of Set 16 | dinguiraye
# Processing Record 21 of Set 16 | itacurubi del rosario
# Processing Record 22 of Set 16 | kourou
# Processing Record 23 of Set 16 | kotido
# Processing Record 24 of Set 16 | keflavik
# Processing Record 25 of Set 16 | kazbegi
# City not found. Skipping...
# Processing Record 26 of Set 16 | ciudad guayana
# Processing Record 27 of Set 16 | vedasandur
# Processing Record 28 of Set 16 | junin
# Processing Record 29 of Set 16 | simeykyne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 724

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Altay  47.8667   88.1167     37.35        37         100
# 1       Chapais  49.7834  -74.8492     60.58        88          96
# 2       Ushuaia -54.8000  -68.3000     49.66        37           0
# 3     Taoudenni  22.6783   -3.9836     83.82        12          92
# 4     Bethlehem  -1.4558  -48.5044     84.24        74          75
# 5         Manta  -0.9500  -80.7333     74.98        69          75
# 6        Urumqi  43.8010   87.6005     36.55        70           0
# 7  Punta Arenas -53.1500  -70.9167     50.11        66         100
# 8         Aktau  43.6500   51.2000     50.58        67         100
# 9        Padang  -0.9492  100.3543     75.27        94         100
#
#    Wind Speed Country                 Date Current Description
# 0        3.60      CN  2022-10-25 21:32:26     overcast clouds
# 1       11.54      CA  2022-10-25 21:32:27     overcast clouds
# 2        8.05      AR  2022-10-25 21:27:29           clear sky
# 3       10.98      ML  2022-10-25 21:27:54     overcast clouds
# 4        9.22      BR  2022-10-25 21:31:04       broken clouds
# 5       10.36      EC  2022-10-25 21:32:27       broken clouds
# 6        2.24      CN  2022-10-25 21:32:27           clear sky
# 7       12.66      CL  2022-10-25 21:28:34          light rain
# 8       12.17      KZ  2022-10-25 21:32:28     overcast clouds
# 9        2.01      ID  2022-10-25 21:28:58       moderate rain

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Altay  47.8667   88.1167     37.35        37         100
# 1       Chapais  49.7834  -74.8492     60.58        88          96
# 2       Ushuaia -54.8000  -68.3000     49.66        37           0
# 3     Taoudenni  22.6783   -3.9836     83.82        12          92
# 4     Bethlehem  -1.4558  -48.5044     84.24        74          75
# 5         Manta  -0.9500  -80.7333     74.98        69          75
# 6        Urumqi  43.8010   87.6005     36.55        70           0
# 7  Punta Arenas -53.1500  -70.9167     50.11        66         100
# 8         Aktau  43.6500   51.2000     50.58        67         100
# 9        Padang  -0.9492  100.3543     75.27        94         100
#
#    Wind Speed Country                 Date Current Description
# 0        3.60      CN  2022-10-25 21:32:26     overcast clouds
# 1       11.54      CA  2022-10-25 21:32:27     overcast clouds
# 2        8.05      AR  2022-10-25 21:27:29           clear sky
# 3       10.98      ML  2022-10-25 21:27:54     overcast clouds
# 4        9.22      BR  2022-10-25 21:31:04       broken clouds
# 5       10.36      EC  2022-10-25 21:32:27       broken clouds
# 6        2.24      CN  2022-10-25 21:32:27           clear sky
# 7       12.66      CL  2022-10-25 21:28:34          light rain
# 8       12.17      KZ  2022-10-25 21:32:28     overcast clouds
# 9        2.01      ID  2022-10-25 21:28:58       moderate rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
city_data_df.count()
# Out:
# City                   724
# Lat                    724
# Lng                    724
# Max Temp               724
# Humidity               724
# Cloudiness             724
# Wind Speed             724
# Country                724
# Date                   724
# Current Description    724
# dtype: int64

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]

# Recreate the DataFrame by using the new column order
city_data_df.count()

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Altay      CN  47.8667   88.1167     37.35        37         100
# 1       Chapais      CA  49.7834  -74.8492     60.58        88          96
# 2       Ushuaia      AR -54.8000  -68.3000     49.66        37           0
# 3     Taoudenni      ML  22.6783   -3.9836     83.82        12          92
# 4     Bethlehem      BR  -1.4558  -48.5044     84.24        74          75
# 5         Manta      EC  -0.9500  -80.7333     74.98        69          75
# 6        Urumqi      CN  43.8010   87.6005     36.55        70           0
# 7  Punta Arenas      CL -53.1500  -70.9167     50.11        66         100
# 8         Aktau      KZ  43.6500   51.2000     50.58        67         100
# 9        Padang      ID  -0.9492  100.3543     75.27        94         100
#
#    Wind Speed Current Description
# 0        3.60     overcast clouds
# 1       11.54     overcast clouds
# 2        8.05           clear sky
# 3       10.98     overcast clouds
# 4        9.22       broken clouds
# 5       10.36       broken clouds
# 6        2.24           clear sky
# 7       12.66          light rain
# 8       12.17     overcast clouds
# 9        2.01       moderate rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
